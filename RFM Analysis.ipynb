# %%
import pandas as pd
from datetime import datetime

# %%
data_type = {
    'customerID': str
}

# %%
df = pd.read_csv('/content/Telco_Customer_Churn_Dataset(s).csv', dtype = data_type, parse_dates = ['tenure'])
# Out:
# <ipython-input-9-064d8c19fed3>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('/content/Telco_Customer_Churn_Dataset(s).csv', dtype = data_type, parse_dates = ['tenure'])

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
columns = ['tenure', 'customerID', 'Contract', 'MonthlyCharges']
df_dataset = df[columns]

# %%
today_date = pd.to_datetime('2022-01-01')

# %%
Rfm_datasets = df_dataset.groupby('customerID').agg({
    'tenure': 'max',
    'Contract': 'first',
    'MonthlyCharges': 'mean'
    })

# %%
Rfm_datasets
# Out:
#            tenure        Contract  MonthlyCharges
# customerID
# 0002-ORFBO      9        One year           65.60
# 0003-MKNFE      9  Month-to-month           59.90
# 0004-TLHLJ      4  Month-to-month           73.90
# 0011-IGKFF     13  Month-to-month           98.00
# 0013-EXCHZ      3  Month-to-month           83.90
# ...           ...             ...             ...
# 9987-LUTYD     13        One year           55.15
# 9992-RRAMN     22  Month-to-month           85.10
# 9992-UJOEL      2  Month-to-month           50.30
# 9993-LHIEB     67        Two year           67.85
# 9995-HOTOH     63        Two year           59.00
#
# [7043 rows x 3 columns]

# %%
Rfm_datasets.rename(columns = {
    'tenure': 'recency',
    'Contract': 'frequency', 'MonthlyCharges':'monetary'
    },
    inplace = True
)

# %%
Rfm_datasets
# Out:
#            recency       frequency  monetary
# customerID
# 0002-ORFBO       9        One year     65.60
# 0003-MKNFE       9  Month-to-month     59.90
# 0004-TLHLJ       4  Month-to-month     73.90
# 0011-IGKFF      13  Month-to-month     98.00
# 0013-EXCHZ       3  Month-to-month     83.90
# ...            ...             ...       ...
# 9987-LUTYD      13        One year     55.15
# 9992-RRAMN      22  Month-to-month     85.10
# 9992-UJOEL       2  Month-to-month     50.30
# 9993-LHIEB      67        Two year     67.85
# 9995-HOTOH      63        Two year     59.00
#
# [7043 rows x 3 columns]

# %%
r = pd.qcut(Rfm_datasets['recency'], q = 5, labels = range(5, 0, -1))
f = pd.qcut(Rfm_datasets['frequency'], q = 5, labels = range(1, 6))
m = pd.qcut(Rfm_datasets['monetary'], q = 5, labels = range(1, 6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-5818beafd836> in <cell line: 1>()
# ----> 1 r = pd.qcut(Rfm_datasets['recency'], q = 5, labels = range(5, 0, -1))
#       2 f = pd.qcut(Rfm_datasets['frequency'], q = 5, labels = range(1, 6))
#       3 m = pd.qcut(Rfm_datasets['monetary'], q = 5, labels = range(1, 6))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     374
#     375     x_np = np.asarray(x)
# --> 376     x_np = x_np[~np.isnan(x_np)]
#     377     bins = np.quantile(x_np, quantiles)
#     378
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
Rfm_datasets['recency'] = pd.to_numeric(Rfm_datasets['recency'])

# %%
Rfm_datasets['recency']
# Out:
# customerID
# 0002-ORFBO     9
# 0003-MKNFE     9
# 0004-TLHLJ     4
# 0011-IGKFF    13
# 0013-EXCHZ     3
#               ..
# 9987-LUTYD    13
# 9992-RRAMN    22
# 9992-UJOEL     2
# 9993-LHIEB    67
# 9995-HOTOH    63
# Name: recency, Length: 7043, dtype: int64
